# %%
from __future__ import division
import time
import torch 
import torch.nn as nn
from torch.autograd import Variable
import numpy as np
import cv2 
from utils import *
import argparse
import os 
import os.path as osp
from darknet import Darknet
import pickle as pkl
import pandas as pd
import random

# %%
def arg_parse():
    """
    Parse arguements to the detect module
    
    """
    
    parser = argparse.ArgumentParser(description='YOLO v3 Detection Module')
   
    parser.add_argument("--images", dest = 'images', help = 
                        "Image / Directory containing images to perform detection upon",
                        default = "imgs", type = str)
    parser.add_argument("--det", dest = 'det', help = 
                        "Image / Directory to store detections to",
                        default = "det", type = str)
    parser.add_argument("--bs", dest = "bs", help = "Batch size", default = 1)
    parser.add_argument("--confidence", dest = "confidence", help = "Object Confidence to filter predictions", default = 0.5)
    parser.add_argument("--nms_thresh", dest = "nms_thresh", help = "NMS Threshhold", default = 0.4)
    parser.add_argument("--cfg", dest = 'cfgfile', help = 
                        "Config file",
                        default = "cfg/yolov3.cfg", type = str)
    parser.add_argument("--weights", dest = 'weightsfile', help = 
                        "weightsfile",
                        default = "yolov3.weights", type = str)
    parser.add_argument("--reso", dest = 'reso', help = 
                        "Input resolution of the network. Increase to increase accuracy. Decrease to increase speed",
                        default = "416", type = str)
    
    return parser.parse_args()
    
args = arg_parse()
images = args.images
batch_size = int(args.bs)
confidence = float(args.confidence)
nms_thesh = float(args.nms_thresh)
start = 0
CUDA = torch.cuda.is_available()
# Out:
# usage: ipykernel_launcher.py [-h] [--images IMAGES] [--det DET] [--bs BS]
#                              [--confidence CONFIDENCE]
#                              [--nms_thresh NMS_THRESH] [--cfg CFGFILE]
#                              [--weights WEIGHTSFILE] [--reso RESO]
# ipykernel_launcher.py: error: unrecognized arguments: -f C:\Users\Shuvam\AppData\Roaming\jupyter\runtime\kernel-0350b496-325a-4b40-9655-c4eb9d1bf78f.json
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 2
# C:\Users\Shuvam\Miniconda3\lib\site-packages\IPython\core\interactiveshell.py:3339: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %%
# Set the location and name of the cfg file
cfg_file = './cfg/yolov3.cfg'

# Set the location and name of the pre-trained weights file
weight_file = './weights/yolov3.weights'

# Set the location and name of the COCO object classes file
namesfile = 'data/coco.names'

# Load the network architecture
m = Darknet(cfg_file)

# Load the pre-trained weights
m.load_weights(weight_file)

# Load the COCO object classes
class_names = load_class_names(namesfile)
# Out:
# Loading weights. Please Wait...100.00% Complete

# %%
cap = cv2.VideoCapture(0)

# %%
colors=[tuple(255 * np.random.rand(3)) for i in range(5)]

# %%
while(cap.isOpened()):
    stime= time.time()
    ret, frame = cap.read()
    # We resize the image to the input width and height of the first layer of the network.    
    frame = cv2.resize(frame, (m.width, m.height))
    boxes = detect_objects(m, frame, iou_thresh=0.4, nms_thresh=0.6)
    if ret:
#         for color, box in zip(colors, boxes):
#             print_objects(boxes, class_names)
#             frame= cv2.rectangle(frame, m.height, m.width, color, 7)
#             frame= cv2.putText(frame, label, tl, cv2.FONT_HERSHEY_TRIPLEX, 1, (0,0,0), 2)
        cv2.imshow('frame', frame)
        print('FPS {:1f}'.format(1/(time.time() -stime)))
        if cv2.waitKey(1)  & 0xFF == ord('q'):
            break
    else:
        break
          
cap.release()
cv2.destroyAllWindows()
# Out:
# It took 1.919 seconds to detect the objects in the image.
#
# Number of Objects Detected: 2
#
# FPS 0.491998
#
#
# It took 1.980 seconds to detect the objects in the image.
#
# Number of Objects Detected: 2
#
# FPS 0.504617
#
#
# It took 1.886 seconds to detect the objects in the image.
#
# Number of Objects Detected: 2
#
# FPS 0.529115
#
#
# It took 1.932 seconds to detect the objects in the image.
#
# Number of Objects Detected: 2
#
# FPS 0.516964
#
#
# It took 2.100 seconds to detect the objects in the image.
#
# Number of Objects Detected: 2
#
# FPS 0.475878
#
#
# It took 1.927 seconds to detect the objects in the image.
#
# Number of Objects Detected: 2
#
# FPS 0.517910
#
#
# It took 1.986 seconds to detect the objects in the image.
#
# Number of Objects Detected: 2
#
# FPS 0.502589
#
#
# It took 1.843 seconds to detect the objects in the image.
#
# Number of Objects Detected: 2
#
# FPS 0.541694
#
#
# It took 2.161 seconds to detect the objects in the image.
#
# Number of Objects Detected: 2
#
# FPS 0.462275
#
#
# It took 2.119 seconds to detect the objects in the image.
#
# Number of Objects Detected: 2
#
# FPS 0.471578
#
#
# It took 2.026 seconds to detect the objects in the image.
#
# Number of Objects Detected: 2
#
# FPS 0.492718
#
#
# It took 2.131 seconds to detect the objects in the image.
#
# Number of Objects Detected: 2
#
# FPS 0.468978
#
#
# It took 2.187 seconds to detect the objects in the image.
#
# Number of Objects Detected: 2
#
# FPS 0.456381
#
#
# It took 2.077 seconds to detect the objects in the image.
#
# Number of Objects Detected: 2
#
# FPS 0.480208
#
#
# It took 1.948 seconds to detect the objects in the image.
#
# Number of Objects Detected: 2
#
# FPS 0.513139
#
#
# It took 1.920 seconds to detect the objects in the image.
#
# Number of Objects Detected: 2
#
# FPS 0.520059
#
#
# It took 1.914 seconds to detect the objects in the image.
#
# Number of Objects Detected: 2
#
# FPS 0.522236
#
#
# It took 1.971 seconds to detect the objects in the image.
#
# Number of Objects Detected: 2
#
# FPS 0.506913
#
#
# It took 1.882 seconds to detect the objects in the image.
#
# Number of Objects Detected: 2
#
# FPS 0.531078
#
#
# It took 1.842 seconds to detect the objects in the image.
#
# Number of Objects Detected: 2
#
# FPS 0.541694
#
#
# It took 1.875 seconds to detect the objects in the image.
#
# Number of Objects Detected: 2
#
# FPS 0.533044
#
#
# It took 2.006 seconds to detect the objects in the image.
#
# Number of Objects Detected: 2
#
# FPS 0.498349
#
#
# It took 2.010 seconds to detect the objects in the image.
#
# Number of Objects Detected: 2
#
# FPS 0.497119
#
#
# It took 1.998 seconds to detect the objects in the image.
#
# Number of Objects Detected: 2
#
# FPS 0.500087
#
#
# It took 2.152 seconds to detect the objects in the image.
#
# Number of Objects Detected: 2
#
# FPS 0.463772
#
#
# It took 1.966 seconds to detect the objects in the image.
#
# Number of Objects Detected: 1
#
# FPS 0.507941
#
#
# It took 2.056 seconds to detect the objects in the image.
#
# Number of Objects Detected: 1
#
# FPS 0.486263
#
#
# It took 1.821 seconds to detect the objects in the image.
#
# Number of Objects Detected: 1
#
# FPS 0.548210
#
#
# It took 1.825 seconds to detect the objects in the image.
#
# Number of Objects Detected: 1
#
# FPS 0.547004
#
#
# It took 1.895 seconds to detect the objects in the image.
#
# Number of Objects Detected: 1
#
# FPS 0.527447
#
#
# It took 2.158 seconds to detect the objects in the image.
#
# Number of Objects Detected: 1
#
# FPS 0.463137
#
#
# It took 2.062 seconds to detect the objects in the image.
#
# Number of Objects Detected: 2
#
# FPS 0.484618
#
#
# It took 2.096 seconds to detect the objects in the image.
#
# Number of Objects Detected: 2
#
# FPS 0.476556
#
#
# It took 1.989 seconds to detect the objects in the image.
#
# Number of Objects Detected: 2
#
# FPS 0.502343
#
#
# It took 1.894 seconds to detect the objects in the image.
#
# Number of Objects Detected: 2
#
# FPS 0.527724
#
#
# It took 1.905 seconds to detect the objects in the image.
#
# Number of Objects Detected: 2
#
# FPS 0.523862
#
#
# It took 2.082 seconds to detect the objects in the image.
#
# Number of Objects Detected: 1
#
# FPS 0.479522
#
#
# It took 2.005 seconds to detect the objects in the image.
#
# Number of Objects Detected: 2
#
# FPS 0.498347
#
#
# It took 2.000 seconds to detect the objects in the image.
#
# Number of Objects Detected: 1
#
# FPS 0.499590
#
#
# It took 2.033 seconds to detect the objects in the image.
#
# Number of Objects Detected: 2
#
# FPS 0.491507
#
#
# It took 2.074 seconds to detect the objects in the image.
#
# Number of Objects Detected: 2
#
# FPS 0.481131
#
#
# It took 1.845 seconds to detect the objects in the image.
#
# Number of Objects Detected: 2
#
# FPS 0.541401
#
#
# It took 2.119 seconds to detect the objects in the image.
#
# Number of Objects Detected: 2
#
# FPS 0.470960
#
#
# It took 1.896 seconds to detect the objects in the image.
#
# Number of Objects Detected: 2
#
# FPS 0.526892
#
#
# It took 1.884 seconds to detect the objects in the image.
#
# Number of Objects Detected: 2
#
# FPS 0.530516
#
#
# It took 1.957 seconds to detect the objects in the image.
#
# Number of Objects Detected: 2
#
# FPS 0.510787
#
#
# It took 1.962 seconds to detect the objects in the image.
#
# Number of Objects Detected: 2
#
# FPS 0.508972
#
#
# It took 2.036 seconds to detect the objects in the image.
#
# Number of Objects Detected: 2
#
# FPS 0.491026
#
#
# It took 1.904 seconds to detect the objects in the image.
#
# Number of Objects Detected: 2
#
# FPS 0.524960
#
#
# It took 1.876 seconds to detect the objects in the image.
#
# Number of Objects Detected: 2
#
# FPS 0.531920
#
#
# It took 1.872 seconds to detect the objects in the image.
#
# Number of Objects Detected: 2
#
# FPS 0.533338
#
#
# It took 1.907 seconds to detect the objects in the image.
#
# Number of Objects Detected: 1
#
# FPS 0.523864
#
#
# It took 2.207 seconds to detect the objects in the image.
#
# Number of Objects Detected: 2
#
# FPS 0.451859
#
#
# It took 2.137 seconds to detect the objects in the image.
#
# Number of Objects Detected: 1
#
# FPS 0.467226
#
#
# It took 1.904 seconds to detect the objects in the image.
#
# Number of Objects Detected: 1
#
# FPS 0.524411
#
#
# It took 1.906 seconds to detect the objects in the image.
#
# Number of Objects Detected: 1
#
# FPS 0.524420
#
#
# It took 1.885 seconds to detect the objects in the image.
#
# Number of Objects Detected: 1
#
# FPS 0.530236
#
#
# It took 1.866 seconds to detect the objects in the image.
#
# Number of Objects Detected: 2
#
# FPS 0.535617
#
#
# It took 1.876 seconds to detect the objects in the image.
#
# Number of Objects Detected: 2
#
# FPS 0.532771
#
#
# It took 1.954 seconds to detect the objects in the image.
#
# Number of Objects Detected: 2
#
# FPS 0.511047
#
#
# It took 2.003 seconds to detect the objects in the image.
#
# Number of Objects Detected: 2
#
# FPS 0.499092
#
#
# It took 2.131 seconds to detect the objects in the image.
#
# Number of Objects Detected: 3
#
# FPS 0.468755
#
#
# It took 1.865 seconds to detect the objects in the image.
#
# Number of Objects Detected: 2
#
# FPS 0.535617
#
#
# It took 2.040 seconds to detect the objects in the image.
#
# Number of Objects Detected: 2
#
# FPS 0.489587
#
#
# It took 2.189 seconds to detect the objects in the image.
#
# Number of Objects Detected: 2
#
# FPS 0.456591
#
#
# It took 2.052 seconds to detect the objects in the image.
#
# Number of Objects Detected: 2
#
# FPS 0.486735
#
#
# It took 2.073 seconds to detect the objects in the image.
#
# Number of Objects Detected: 2
#
# FPS 0.481824
#
#
# It took 1.896 seconds to detect the objects in the image.
#
# Number of Objects Detected: 1
#
# FPS 0.527169
#
#
# It took 1.910 seconds to detect the objects in the image.
#
# Number of Objects Detected: 1
#
# FPS 0.523327
#
#
# It took 1.909 seconds to detect the objects in the image.
#
# Number of Objects Detected: 1
#
# FPS 0.523316
#
#
# It took 2.184 seconds to detect the objects in the image.
#
# Number of Objects Detected: 1
#
# FPS 0.457633
#
#
# It took 1.900 seconds to detect the objects in the image.
#
# Number of Objects Detected: 2
#
# FPS 0.525511
#
#
# It took 1.908 seconds to detect the objects in the image.
#
# Number of Objects Detected: 1
#
# FPS 0.523863
#
#
# It took 1.961 seconds to detect the objects in the image.
#
# Number of Objects Detected: 1
#
# FPS 0.509748
#
#
# It took 1.998 seconds to detect the objects in the image.
#
# Number of Objects Detected: 1
#
# FPS 0.500094

# %%
cap.release()
cv2.destroyAllWindows()

# %%
while(cap.isOpened()):
    stime= time.time()
    ret, frame = cap.read()
    results = tfnet.return_predict(frame)
    if ret:
        for color, result in zip(colors, results):
            tl = (result['topleft']['x'], result['topleft']['y'])
            br = (result['bottomright']['x'], result['bottomright']['y'])
            label = result['label']
            frame= cv2.rectangle(frame, tl, br, color, 7)
            frame= cv2.putText(frame, label, tl, cv2.FONT_HERSHEY_TRIPLEX, 1, (0,0,0), 2)
        cv2.imshow('frame', frame)
        print('FPS {:1f}'.format(1/(time.time() -stime)))
        if cv2.waitKey(1)  & 0xFF == ord('q'):
            break
    else:
        break
          
cap.release()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-f37fc138f140> in <module>
#       2     stime= time.time()
#       3     ret, frame = cap.read()
# ----> 4     results = tfnet.return_predict(frame)
#       5     if ret:
#       6         for color, result in zip(colors, results):
#
# NameError: name 'tfnet' is not defined
